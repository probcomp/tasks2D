# %%
import Pkg
Pkg.activate("../../Tasks2D")
# Out:
#   Activating project at `~/Developer/tasks2D/Tasks2D`

# %%
using Revise
using Plots
import LineWorlds
const L = LineWorlds
# Out:
# LineWorlds

# %%
Geo = L.Geometry
# Out:
# LineWorlds.Geometry

# %%
# _segs, _bb, _ = L.load_env_sparse("../../data/environments/000d0395709d2a16e195c6f0189155c4.json");
_segs, _bb = L.load_env_sparse("../../data/environments/ambig.json")
# Out:
# (_segs = LineWorlds.Geometry.Segment[LineWorlds.Geometry.Segment([0.0, 0.0], [4.5, 0.0]), LineWorlds.Geometry.Segment([4.5, 0.0], [4.5, 12.0]), LineWorlds.Geometry.Segment([4.5, 12.0], [0.0, 12.0]), LineWorlds.Geometry.Segment([0.0, 12.0], [0.0, 0.0]), LineWorlds.Geometry.Segment([0.0, 0.0], [0.0, 2.0]), LineWorlds.Geometry.Segment([0.0, 2.0], [4.0, 2.0]), LineWorlds.Geometry.Segment([4.0, 2.0], [4.0, 3.0]), LineWorlds.Geometry.Segment([4.0, 3.0], [4.0, 2.0]), LineWorlds.Geometry.Segment([4.0, 2.0], [0.0, 2.0]), LineWorlds.Geometry.Segment([0.0, 2.0], [0.0, 6.0])  …  LineWorlds.Geometry.Segment([4.0, 6.0], [4.0, 7.0]), LineWorlds.Geometry.Segment([4.0, 7.0], [4.0, 6.0]), LineWorlds.Geometry.Segment([4.0, 6.0], [0.0, 6.0]), LineWorlds.Geometry.Segment([0.0, 6.0], [0.0, 10.0]), LineWorlds.Geometry.Segment([0.0, 10.0], [4.0, 10.0]), LineWorlds.Geometry.Segment([4.0, 10.0], [4.0, 8.0]), LineWorlds.Geometry.Segment([4.0, 8.0], [4.0, 10.0]), LineWorlds.Geometry.Segment([4.0, 10.0], [0.0, 1
# ...

# %%
mypl = plot(
    size=(500,500), aspect_ratio=:equal, grid=false,
    xlim=(_bb[1][1]-3, _bb[2][1]+3),
    ylim=(_bb[1][2]-3, _bb[2][2]+3),
    legend=:bottomleft,
)
plot!(_segs, c=:black, linewidth=1, label="Map")

# %%
verts = [[8.9, 0.1], [8.89, 0.11], [6.51, 0.11], [6.5, 0.12], [6.5, 3.08], [8.48, 3.08], [8.49, 3.09], [8.49, 3.19], [8.48, 3.2], [8.47, 3.19], [8.46, 3.19], [8.45, 3.2], [6.5, 3.2], [6.5, 4.54], [6.49, 4.55], [6.39, 4.55], [6.38, 4.54], [6.38, 3.2], [0.11, 3.2], [0.1, 3.21], [0.1, 8.72], [6.38, 8.72], [6.38, 6.49], [6.39, 6.48], [6.49, 6.48], [6.5, 6.49], [6.49, 6.5], [6.49, 6.54], [6.5, 6.55], [6.5, 8.83], [6.51, 8.84], [6.51, 10.42], [6.56, 10.47], [6.57, 10.47], [6.64, 10.54], [6.65, 10.54], [6.72, 10.61], [6.73, 10.61], [6.81, 10.69], [6.82, 10.69], [6.89, 10.76], [6.9, 10.76], [6.97, 10.83], [6.98, 10.83], [7.06, 10.91], [7.07, 10.91], [7.14